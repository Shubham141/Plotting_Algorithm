# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set()

# %% [markdown]
# ### Path

# %%
df=pd.read_csv("/home/shubham/Downloads/Automobile_data.csv")
df.shape
# Out:
# (205, 26)

# %%
df.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 205 entries, 0 to 204
# Data columns (total 26 columns):
# symboling            205 non-null int64
# normalized-losses    205 non-null object
# make                 205 non-null object
# fuel-type            205 non-null object
# aspiration           205 non-null object
# num-of-doors         205 non-null object
# body-style           205 non-null object
# drive-wheels         205 non-null object
# engine-location      205 non-null object
# wheel-base           205 non-null float64
# length               205 non-null float64
# width                205 non-null float64
# height               205 non-null float64
# curb-weight          205 non-null int64
# engine-type          205 non-null object
# num-of-cylinders     205 non-null object
# engine-size          205 non-null int64
# fuel-system          205 non-null object
# bore                 205 non-null object
# stroke               205 non-null object
# ...

# %%
df.describe()
# Out:
#         symboling  wheel-base      length       width      height  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000
# mean     0.834146   98.756585  174.049268   65.907805   53.724878
# std      1.245307    6.021776   12.337289    2.145204    2.443522
# min     -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000   94.500000  166.300000   64.100000   52.000000
# 50%      1.000000   97.000000  173.200000   65.500000   54.100000
# 75%      2.000000  102.400000  183.100000   66.900000   55.500000
# max      3.000000  120.900000  208.100000   72.300000   59.800000
#
#        curb-weight  engine-size  compression-ratio    city-mpg  highway-mpg
# count   205.000000   205.000000         205.000000  205.000000   205.000000
# mean   2555.565854   126.907317          10.142537   25.219512    30.751220
# std     520.680204    41.642693           3.972040    6.542142     6.886443
# ...

# %%
df.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...    engine-size  \
# 0  convertible          rwd           front        88.6  ...            130
# 1  convertible          rwd           front        88.6  ...            130
# 2    hatchback          rwd           front        94.5  ...            152
# 3        sedan          fwd           front        99.8  ...            109
# 4        sedan          4wd           front        99.4  ...            136
#
# ...

# %%
df['normalized-losses'].value_counts()
# Out:
# ?      41
# 161    11
# 91      8
# 150     7
# 134     6
# 128     6
# 104     6
# 74      5
# 85      5
# 95      5
# 65      5
# 103     5
# 168     5
# 102     5
# 94      5
# 122     4
# 148     4
# 93      4
# 118     4
# 106     4
# 101     3
# 115     3
# 154     3
# 83      3
# 137     3
# 125     3
# 108     2
# 81      2
# 119     2
# 194     2
# 87      2
# 89      2
# 110     2
# 129     2
# 192     2
# 188     2
# 197     2
# 164     2
# 145     2
# 158     2
# 153     2
# 113     2
# 121     1
# 231     1
# 78      1
# 107     1
# 186     1
# 90      1
# 142     1
# 77      1
# 98      1
# 256     1
# Name: normalized-losses, dtype: int64

# %%
df['normalized-losses']= df['normalized-losses'].apply(lambda x: 0 if x=='?' else int(x))

# %%
df.head()
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3                  0  alfa-romero       gas        std
# 1          3                  0  alfa-romero       gas        std
# 2          1                  0  alfa-romero       gas        std
# 3          2                164         audi       gas        std
# 4          2                164         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...    \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two  convertible          rwd           front        88.6  ...
# 2          two    hatchback          rwd           front        94.5  ...
# 3         four        sedan          fwd           front        99.8  ...
# 4         four        sedan          4wd           front        99.4  ...
#
#    engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# ...

# %%
x=df['normalized-losses'].loc[df['normalized-losses']!=0].values

# %%
x
# Out:
# array([164, 164, 158, 158, 192, 192, 188, 188, 121,  98,  81, 118, 118,
#        118, 148, 148, 148, 148, 110, 145, 137, 137, 101, 101, 101, 110,
#         78, 106, 106,  85,  85,  85, 107, 145, 104, 104, 104, 113, 113,
#        150, 150, 150, 150, 129, 115, 129, 115, 115, 118,  93,  93,  93,
#         93, 142, 161, 161, 161, 161, 153, 153, 125, 125, 125, 137, 128,
#        128, 128, 122, 103, 128, 128, 122, 103, 168, 106, 106, 128, 108,
#        108, 194, 194, 231, 161, 161, 161, 161, 161, 161, 161, 119, 119,
#        154, 154, 154,  74, 186, 150, 104, 150, 104, 150, 104,  83,  83,
#         83, 102, 102, 102, 102, 102,  89,  89,  85,  85,  87,  87,  74,
#         77,  81,  91,  91,  91,  91,  91,  91,  91,  91, 168, 168, 168,
#        168, 134, 134, 134, 134, 134, 134,  65,  65,  65,  65,  65, 197,
#        197,  90, 122, 122,  94,  94,  94,  94,  94, 256, 103,  74, 103,
#         74, 103,  74,  95,  95,  95,  95,  95])

# %%
x.mean()
# Out:
# 122.0

# %%
df['normalized-losses']= df['normalized-losses'].apply(lambda i: x.mean() if i==0 else i)

# %%
df.head()
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3                122  alfa-romero       gas        std
# 1          3                122  alfa-romero       gas        std
# 2          1                122  alfa-romero       gas        std
# 3          2                164         audi       gas        std
# 4          2                164         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...    \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two  convertible          rwd           front        88.6  ...
# 2          two    hatchback          rwd           front        94.5  ...
# 3         four        sedan          fwd           front        99.8  ...
# 4         four        sedan          4wd           front        99.4  ...
#
#    engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# ...

# %%
df['price'].values
# Out:
# array(['13495', '16500', '16500', '13950', '17450', '15250', '17710',
#        '18920', '23875', '?', '16430', '16925', '20970', '21105', '24565',
#        '30760', '41315', '36880', '5151', '6295', '6575', '5572', '6377',
#        '7957', '6229', '6692', '7609', '8558', '8921', '12964', '6479',
#        '6855', '5399', '6529', '7129', '7295', '7295', '7895', '9095',
#        '8845', '10295', '12945', '10345', '6785', '?', '?', '11048',
#        '32250', '35550', '36000', '5195', '6095', '6795', '6695', '7395',
#        '10945', '11845', '13645', '15645', '8845', '8495', '10595',
#        '10245', '10795', '11245', '18280', '18344', '25552', '28248',
#        '28176', '31600', '34184', '35056', '40960', '45400', '16503',
#        '5389', '6189', '6669', '7689', '9959', '8499', '12629', '14869',
#        '14489', '6989', '8189', '9279', '9279', '5499', '7099', '6649',
#        '6849', '7349', '7299', '7799', '7499', '7999', '8249', '8949',
# ...

# %% [markdown]
# ### The Price of cleaning

# %%
df.price.str.isnumeric().value_counts()
# Out:
# True     201
# False      4
# Name: price, dtype: int64

# %%
df['price']= df['price'].apply(lambda x: 0 if x=='?' else int(x))

# %%
x=df['price'].loc[df['price']!=0].values

# %%
df['price']= df['price'].apply(lambda i: x.mean() if i==0 else i)

# %% [markdown]
# ### Cleaning Bore

# %%
df['bore'].loc[df['bore']=='?']
# Out:
# 55    ?
# 56    ?
# 57    ?
# 58    ?
# Name: bore, dtype: object

# %%
df['bore']= df['bore'].apply(lambda x: 0 if x=='?' else float(x))
x=df['bore'].loc[df['bore']!=0].values
df['bore']= df['bore'].apply(lambda i: x.mean() if i==0 else i)

# %% [markdown]
# ### Cleaning Horsepower

# %%
df['horsepower'].loc[df['horsepower'].str.isnumeric()==False]
# Out:
# 130    ?
# 131    ?
# Name: horsepower, dtype: object

# %%
df['horsepower']= df['horsepower'].apply(lambda x: 0 if x=='?' else float(x))
x=df['horsepower'].loc[df['horsepower']!=0].values
df['horsepower']= df['horsepower'].apply(lambda i: x.mean() if i==0 else i)

# %%
df['num-of-cylinders'].value_counts()
# Out:
# four      159
# six        24
# five       11
# eight       5
# two         4
# three       1
# twelve      1
# Name: num-of-cylinders, dtype: int64

# %% [markdown]
# ### Cleaning Peak-rpm

# %%
df['peak-rpm'].loc[df['peak-rpm'].str.isnumeric()==False]
# Out:
# 130    ?
# 131    ?
# Name: peak-rpm, dtype: object

# %%
df['peak-rpm']= df['peak-rpm'].apply(lambda x: 0 if x=='?' else int(x))
x=df['peak-rpm'].loc[df['peak-rpm']!=0].values
df['peak-rpm']= df['peak-rpm'].apply(lambda i: x.mean() if i==0 else i)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 205 entries, 0 to 204
# Data columns (total 26 columns):
# symboling            205 non-null int64
# normalized-losses    205 non-null float64
# make                 205 non-null object
# fuel-type            205 non-null object
# aspiration           205 non-null object
# num-of-doors         205 non-null object
# body-style           205 non-null object
# drive-wheels         205 non-null object
# engine-location      205 non-null object
# wheel-base           205 non-null float64
# length               205 non-null float64
# width                205 non-null float64
# height               205 non-null float64
# curb-weight          205 non-null int64
# engine-type          205 non-null object
# num-of-cylinders     205 non-null object
# engine-size          205 non-null int64
# fuel-system          205 non-null object
# bore                 205 non-null float64
# stroke               205 non-null object
# ...

# %%
plt.figure(figsize=(8, 8))
plt.hist(df.price, bins=40);

# %%
plt.figure(figsize=(8, 8))
df['body-style'].value_counts().plot(kind='bar', rot=0, legend=True);

# %%
plt.figure(figsize=(8, 8))
df['fuel-type'].value_counts().plot(kind='bar', rot=0, legend=True);

# %%
df['aspiration'].value_counts().plot.pie(figsize=(6, 6), autopct='%.2f', fontsize=12)
plt.title("Aspiration type pie diagram")
plt.ylabel('Number of vehicles')
plt.xlabel('Fuel type');

# %%
plt.figure(figsize=(8, 8))
df['drive-wheels'].value_counts().plot(kind='bar', rot=0)
plt.title("Drive wheels diagram")
plt.ylabel('Number of vehicles')
plt.xlabel('Drive wheels');

# %%
df.make.value_counts().plot(kind='bar', figsize=(18 ,10), rot=90, fontsize=10)
plt.title("Number of vehicles by make")
plt.ylabel('Number of vehicles')
plt.xlabel('Make');

# %% [markdown]
# ### Boxplot Analysis

# %%
plt.figure(figsize=(20 ,15))
sns.boxplot(x=df.make, y=df.price);

# %%
plt.figure(figsize=(10 ,8))
sns.boxplot(x=df['fuel-type'], y=df['price']);

# %%
plt.figure(figsize=(10 ,10))
sns.jointplot(df.price, df['engine-size'], color='r', kind='reg');

# %%
plt.figure(figsize=(10, 10))
sns.boxplot(x=df['body-style'], y=df.price);

# %%
plt.figure(figsize=(18 ,10))
df.groupby('body-style')['make'].value_counts().plot(kind='bar');
plt.ylabel("NO. of Cars");

# %% [markdown]
# ### Jointplot Analysis

# %%
plt.figure(figsize=(10 ,10))
sns.jointplot(df.horsepower, df['peak-rpm'], kind='reg', color='darkorange');

# %%
plt.figure(figsize=(10 ,10))
sns.jointplot(df['wheel-base'], df['peak-rpm'], kind='reg', color='darkorange');

# %% [markdown]
# ### Heatmap Analysis

# %%
plt.figure(figsize=(13,10))
sns.heatmap(df.corr(), annot=True, fmt='.2f', linewidths=0.2)
